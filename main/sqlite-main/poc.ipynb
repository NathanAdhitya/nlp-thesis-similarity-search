# %%
# %pip install sqlite-vec
# Out:
# Requirement already satisfied: sqlite-vec in c:\users\2ndro\anaconda3\envs\bge-m3\lib\site-packages (0.1.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sqlite3
import sqlite_vec

db = sqlite3.connect("../../data/cleaned_with_bge_m3.db")
db.enable_load_extension(True)
sqlite_vec.load(db)
db.enable_load_extension(False)

# %%
db.execute("SELECT vec_version()").fetchone()
# Out:
# ('v0.1.6',)

# %%
# Get all tables in the database
tables = db.execute("SELECT name FROM sqlite_master WHERE type='table';").fetchall()

# Print the tables in a more readable format
print("Tables in the database:")
print("=" * 30)
for i, table in enumerate(tables, 1):
    print(f"{i}. {table[0]}")
# Out:
# Tables in the database:
# ==============================
# 1. users
# 2. publications
# 3. sqlite_sequence
# 4. publication_user_mapping
# 5. publications_vec_bge_m3_info
# 6. publications_vec_bge_m3_chunks
# 7. publications_vec_bge_m3_rowids
# 8. publications_vec_bge_m3_vector_chunks00
# 9. publications_vec_all_MiniLM_L6_v2_info
# 10. publications_vec_all_MiniLM_L6_v2_chunks
# 11. publications_vec_all_MiniLM_L6_v2_rowids
# 12. publications_vec_all_MiniLM_L6_v2_vector_chunks00
# 13. publications_vec_indobert_info
# 14. publications_vec_indobert_chunks
# 15. publications_vec_indobert_rowids
# 16. publications_vec_indobert_vector_chunks00
# 17. publications_vec_bge_m3
# 18. publications_vec_all_MiniLM_L6_v2
# 19. publications_vec_indobert

# %%
# tables = db.execute("SELECT publication_id FROM publications_vec_bge_m3;").fetchall()
# print(len(tables))
column_names = db.execute("PRAGMA table_info(publications_vec_bge_m3)").fetchall()
print(column_names)
tables = db.execute("SELECT * FROM publications_vec_bge_m3 LIMIT 1;").fetchall()
print(tables)
# tables = db.execute("SELECT * FROM users;").fetchall()
# print(len(tables))
# column_names = db.execute("PRAGMA table_info(users)").fetchall()
# print(column_names)
# for row in tables:
#     print(row)
# Out:
# [(0, 'publication_id', '', 1, None, 1), (1, 'embedding', '', 0, None, 0)]
# [(1, b'\xe2\xc7f\xbc\x7f0\x889|W\x12\xbc\x15S\xe1<~\xf1*\xbc\xbb\x88\xca<a)\xcf;,\x93Q\xbc9\xc0\xc5\xbcP\xcb(<\x08\x9e\xc5\xbc\x82\x14\x97\xbb\x03{\xb1\xbc\t\xf8\xda\xba(\xcd0\xbd\xf9b\xb7<\xef\xce)=\xeb\xc6\xee\xbc\t\xe8*\xbd\x9a\xf71\xbd\xf4\x0eS<\xadrJ\xbc\x8a.\x93\xbb\xf0\x16`\xbd\xfa&\xb3\xbc\xd1\x18\xaf<\xdeN\x00\xbc\xb5\xb6\xcc\xbcS\xa3\x95\xbc\x82\xf2\x12\xbb<\xb8\x94\xbc\xfb\x85\x0f=\x99\xa23=o\x0f\xb1\xbbq\xa20\xbd\xd9\xe2!\xbdz\xf6\xcb:\x92^\x1b\xbd=\xed\xab\xbcX\xb29=\x0b\xbdw=\x0e\x12\x06\xbc\xfd$\xc2\xbb\xfe\x10\xcf\xbc\x85\x87\x81<\x93\xed\x81\xbd\x93\xa74<(
# %%
# Generate embeddings for the publications
from FlagEmbedding import BGEM3FlagModel

model = BGEM3FlagModel('BAAI/bge-m3',  
                       use_fp16=True) # Setting use_fp16 to True speeds up computation with a slight performance degradation

print(model)
# Out:
# Fetching 30 files: 100%|██████████| 30/30 [00:00<?, ?it/s]
# <FlagEmbedding.inference.embedder.encoder_only.m3.M3Embedder object at 0x000001ED3F9FEE50>

# %%
search_query = "generative ai"

# Generate embedding for the search query
if search_query.strip():
    query_embedding = model.encode([search_query])['dense_vecs'][0]
    
    # Perform KNN search to get top 100 matches
    cursor = db.execute('''
    SELECT publication_id, distance 
    FROM publications_vec_bge_m3 
    WHERE embedding MATCH ? 
    ORDER BY distance 
    LIMIT 100
    ''', [query_embedding])
    
    matches = cursor.fetchall()
    
    if matches:
        # Get publication details and authors for each match
        publication_ids = [str(match[0]) for match in matches]
        placeholders = ','.join(['?'] * len(publication_ids))
        
        query = f'''
        SELECT p.id, p.title, GROUP_CONCAT(u.name, '; ') as authors
        FROM publications p
        LEFT JOIN publication_user_mapping pum ON p.id = pum.publication_id
        LEFT JOIN users u ON pum.user_id = u.id
        WHERE p.id IN ({placeholders})
        GROUP BY p.id, p.title
        ORDER BY CASE p.id {' '.join([f'WHEN {pid} THEN {i}' for i, pid in enumerate(publication_ids)])} END
        '''
        
        cursor = db.execute(query, publication_ids)
        results = cursor.fetchall()
        
        # Compile top users
        user_counts = {}
        for _, _, users in results:
            if users:
                for author in users.split('; '):
                    author = author.strip()
                    if author:
                        user_counts[author] = user_counts.get(author, 0) + 1
        
        # Sort users by frequency
        top_users = sorted(user_counts.items(), key=lambda x: x[1], reverse=True)

        # Print results
        print(f"Top 100 matches for query: '{search_query}'")
        print("=" * 50)
        for i, (pub_id, title, users) in enumerate(results, 1):
            distance = next(match[1] for match in matches if match[0] == pub_id)
            print(f"{i}. [{pub_id}] {title}")
            print(f"   Users: {users if users else 'No users found'}")
            print(f"   Distance: {distance:.4f}")
            print()

        print("\nTop Users in Results:")
        print("=" * 30)
        for i, (user, count) in enumerate(top_users[:20], 1):
            print(f"{i}. {user} ({count} publications)")

    else:
        print("No matches found for the query.")
else:
    print("Search query is empty. Please set the search_query variable.")
# Out:
# Top 100 matches for query: 'generative ai'
# ==================================================
# 1. [32721] Kecerdasan buatan dengan metode ID3 finite state machine dalam turn-based strategy game
#    Users: Leo Willyanto Santoso; Liliana
#    Distance: 0.8765
#
# 2. [37428] Pengembangan aplikasi chatbot menggunakan LLAMA 2 dan framework Flutter sebagai tools dalam studi Alkitab
#    Users: Henry Novianus Palit; Alexander Setiawan
#    Distance: 0.8946
#
# 3. [35918] Generator musik menggunakan generative adversarial network untuk generasi musik klasik
#    Users: Henry Novianus Palit; Kartika Gunadi
#    Distance: 0.9039
#
# 4. [41694] Kecerdasan buatan dengan metode ID3 finite state machine dalam turn-based tactics game
#    Users: Leo Willyanto Santoso
#    Distance: 0.9126
#
# 5. [37914] Implementasi kecerdasan buatan pada tahap design thinking dalam perancangan interior. Studi kasus mahasiswa Universitas Kristen Petra program studi Desain Interior
#    Users: No users found
#    Distance: 0.9368
#
# 6. [24858] Pembuatan AI untuk turn-based strategy games menggunakan metode adaptive spatial reasoning
#    Users: Gregorius Satiabudhi; Liliana
#    Distance: 0.9467
#
# 7. [42824] Promoting Meaningful Learning in the Age of Artificial Intelligence
#    Users: Flora Debora Floris
#    Distance: 0.9491
#
# 8. [21401] Pembuatan turn based strategy role playing game menggunakan neural network dan decision tree
#    Users: Gregorius Satiabudhi; Liliana
#    Distance: 0.9512
#
# 9. [31142] Penerapan probabilistic finite state machine pada AI musuh dalam game action RPG untuk membuat gerakan AI tidak monoton
#    Users: Djoni Haryadi Setiabudi; Hans Juwiantho
#    Distance: 0.9519
#
# 10. [41112] Perancangan dan pembuatan aplikasi untuk mengoptimasi penyusunan iklan gambar dengan metode algoritma genetik
#    Users: Rolly Intan; Leo Willyanto Santoso
#    Distance: 0.9588
#
# 11. [31545] Perancangan dan pembuatan software artificial intelligence untuk game bomb fighter dengan fasilitas multiplayer
#    Users: Gregorius Satiabudhi; Irwan Kristanto Julistiono
#    Distance: 0.9602
#
# 12. [34862] Automatic synchronization between videos and haptic devices
#    Users: Rafayel Avetyan; Lute Van Oosten
#    Distance: 0.9629
#
# 13. [35687] Multi agent reinforcement learning untuk pembuatan artificial intelligence pada game tactical shooter
#    Users: Andre Gunawan; Liliana
#    Distance: 0.9634
#
# 14. [45018] Pemanfaatan AI (Artificial Intelligence) Gemini dalam Bedah Karakteristik Arsitektur, Gaya Desain interior dan Ragam Hias pada Film Bumi Manusia (2019)
#    Users: Dr. Laksmi Kusuma Wardani
#    Distance: 0.9646
#
# 15. [44173] PENERAPAN METODE ARTIFICIAL INTELLIGENCE UNTUK PREDIKSI BIAYA AWAL PROYEK KONSTRUKSI BANGUNAN
#    Users: Doddy Prayogo
#    Distance: 0.9677
#
# 16. [32584] Penerapan metode goal oriented action planning untuk agent ai pada turn based tactics video game
#    Users: Hans Juwiantho; Liliana
#    Distance: 0.9698
#
# 17. [31261] Pemodelan mix design beton dengan least squares support vector machine – particle swarm optimization
#    Users: Pamuda Pudjisuryadi; Doddy Prayogo
#    Distance: 0.9699
#
# 18. [31259] Pemodelan mix design beton dengan least squares support vector machine – particle swarm optimization
#    Users: Pamuda Pudjisuryadi; Doddy Prayogo
#    Distance: 0.9699
#
# 19. [41955] Object as Portal
#    Users: Bramasta Putra Redyantanu
#    Distance: 0.9710
#
# 20. [25802] Perbandingan performa turn-based game menggunakan algoritma genetika dan logika fuzzy
#    Users: Rolly Intan; Kristo Radion Purba S.St
#    Distance: 0.9715
#
# 21. [35643] Global illumination rendering menggunakan pix2pix generative adversarial networks secara real time
#    Users: Alvin Nathaniel Tjondrowiguno; Liliana
#    Distance: 0.9739
#
# 22. [44739] Custom Built of Smart Computing Platform for Supporting Optimization Methods and Artificial Intelligence Research: PakCarik: GPU-Accelerated Platform for AI Researches
#    Users: Resmana Lim; Doddy Prayogo; Felix Pasila; Agustinus Noertjahyana; Indar Sugiarto
#    Distance: 0.9743
#
# 23. [44639] Custom Built of Smart Computing Platform for Supporting Optimization Methods and Artificial Intelligence Research: PakCarik: GPU-Accelerated Platform for AI Researches
#    Users: Resmana Lim; Doddy Prayogo; Felix Pasila; Agustinus Noertjahyana; Indar Sugiarto
#    Distance: 0.9743
#
# 24. [44125] Custom Built of Smart Computing Platform for Supporting Optimization Methods and Artificial Intelligence Research: PakCarik: GPU-Accelerated Platform for AI Researches
#    Users: Resmana Lim; Doddy Prayogo; Felix Pasila; Agustinus Noertjahyana; Indar Sugiarto
#    Distance: 0.9743
#
# 25. [45470] Custom Built of Smart Computing Platform for Supporting Optimization Methods and Artificial Intelligence Research: PakCarik: GPU-Accelerated Platform for AI Researches
#    Users: Resmana Lim; Doddy Prayogo; Felix Pasila; Agustinus Noertjahyana; Indar Sugiarto
#    Distance: 0.9743
#
# 26. [45017] Peranan Artificial Intelligence Dalam Membantu Efisiensi Dan Efektivitas Proses Perancangan Interior
#    Users: Dr. Laksmi Kusuma Wardani
#    Distance: 0.9744
#
# 27. [11817] Penerapan algoritma genetika dalam pembuatan perencanaan produksi di PT. "X"
#    Users: I Gede Agus Widyadana
#    Distance: 0.9751
#
# 28. [19027] Perbandingan algoritma simulated annealing neighborhood generation dengan algoritma simulated annealing dan genetic algorithm pada permasalahan tata letak fasilitas
#    Users: No users found
#    Distance: 0.9770
#
# 29. [30981] Adaptive AI pada survival horror game menggunakan Fuzzy
#    Users: Rolly Intan; Hans Juwiantho
#    Distance: 0.9777
#
# 30. [3608] Penjadwalan produksi pada PT. "X" dengan pendekatan algoritma genetika
#    Users: Pauline Astari Singgih
#    Distance: 0.9780
#
# 31. [44413] Implementing the use of ai for analysis and prediction in the fashion industry
#    Users: Luri Renaningtyas
#    Distance: 0.9789
#
# 32. [44007] Performance analysis of a parallel genetic algorithm: A case study of the traveling salesman problem
#    Users: Doddy Prayogo; Henry Novianus Palit; Indar Sugiarto
#    Distance: 0.9799
#
# 33. [44187] Performance analysis of a parallel genetic algorithm: A case study of the traveling salesman problem
#    Users: Doddy Prayogo; Henry Novianus Palit; Indar Sugiarto
#    Distance: 0.9799
#
# 34. [45464] Performance analysis of a parallel genetic algorithm: A case study of the traveling salesman problem
#    Users: Doddy Prayogo; Henry Novianus Palit; Indar Sugiarto
#    Distance: 0.9799
#
# 35. [30779] Menghasilkan background game music dengan menggunakan deep convolutional generative adversarial network
#    Users: Henry Novianus Palit; Alvin Nathaniel Tjondrowiguno
#    Distance: 0.9806
#
# 36. [30912] Penerapan Finite State Machine dan Atreus AI Behavior pada AI Musuh dalam Fighting game
#    Users: Djoni Haryadi Setiabudi; Hans Juwiantho
#    Distance: 0.9834
#
# 37. [42238] A multiobjective evolutionary algorithm for achieving energy efficiency in production environments integrated with multiple automated guided vehicles
#    Users: Gregorius Satia Budhi
#    Distance: 0.9835
#
# 38. [3609] Studi perancangan arsitektur metode optimasi genetic algorithms berbasis kompiler HDL foundation versi 2.1
#    Users: Yohanes Trilaksono Dibyo S
#    Distance: 0.9836
#
# 39. [22104] Aplikasi game strategi penyerbuan di Batavia tahun 1628 oleh Kesultanan Mataram menggunakan metode algoritma genetika
#    Users: Kristo Radion Purba S.St; Liliana
#    Distance: 0.9845
#
# 40. [43919] Machine Learning
#    Users: Leo Willyanto Santoso
#    Distance: 0.9848
#
# 41. [36861] Pengembangan model prediksi durasi rencana proyek konstruksi dengan metode artificial intelligence
#    Users: Doddy Prayogo
#    Distance: 0.9863
#
# 42. [44957] Exploring AI Chatbot Development for Gen-Z: A Study on First-Time and Experienced Voters in Pemilu
#    Users: Lady Joanne Tjahyana
#    Distance: 0.9864
#
# 43. [5230] Perencanaan dan pembuatan penerjemah bahasa Inggris ke bahasa Indonesia dengan menggunakan pengolahan bahasa alami (natural language processing)
#    Users: Rolly Intan
#    Distance: 0.9886
#
# 44. [11806] Penerapan algoritma genetik pada perencanaan multi produk di PT. X
#    Users: I Gede Agus Widyadana
#    Distance: 0.9936
#
# 45. [37585] Penerimaan pengguna Instagram terhadap user-generated aesthetic di akun Instagram Ankayama
#    Users: Daniel Budiana; Lady Joanne Tjahyana
#    Distance: 0.9939
#
# 46. [41683] Pewarnaan Otomatis Sketsa Gambar Menggunakan Metode Conditional GAN Untuk Mempercepat Proses Pewarnaan
#    Users: Liliana .
#    Distance: 0.9941
#
# 47. [43519] Pewarnaan Otomatis Sketsa Gambar Menggunakan Metode Conditional GAN Untuk Mempercepat Proses Pewarnaan
#    Users: Djoni Haryadi Setiabudi
#    Distance: 0.9941
#
# 48. [34379] Pewarnaan dan shading otomatis sketsa gambar menggunakan metode conditional - gan
#    Users: Djoni Haryadi Setiabudi; Liliana
#    Distance: 0.9944
#
# 49. [18162] Aplikasi game yang menerapkan metode autonomous NPC untuk mengkoordinasi AI dari enemy
#    Users: Gregorius Satiabudhi
#    Distance: 0.9944
#
# 50. [35565] Procedural content generator untuk menghasilkan maze yang memiliki alogoritma jalan keluar yang dinamis pada game menggunakan algoritma recursive backtraking, penghancuran dinding maze, dan penempatan non-player character
#    Users: Liliana
#    Distance: 0.9945
#
# 51. [36785] Variatif AI untuk perilaku NPC di game horror dengan menggunakan metode behavior tree
#    Users: Leo Willyanto Santoso
#    Distance: 0.9952
#
# 52. [2359] Estimasi parameter space-time modeling dengan menggunakan genetic algorithm
#    Users: Siana Halim; Indriati Njoto Bisono
#    Distance: 0.9957
#
# 53. [22089] Implementasi rule base system dan fuzzy logic artificial intelligence pada game kartu capsa
#    Users: Gregorius Satiabudhi; Liliana
#    Distance: 0.9958
#
# 54. [23781] Pembuatan game dengan menerapkan metode decision tree : UCB1, untuk menentukan pemilihan strategy dalam AI
#    Users: Rolly Intan; Gregorius Satiabudhi
#    Distance: 0.9958
#
# 55. [41954] Object as Portal: Actual-Virtual Multi-Space of Temporary Urban Games Space
#    Users: Bramasta Putra Redyantanu
#    Distance: 0.9965
#
# 56. [37423] Pembuatan aplikasi chatbot kerohanian berbasis retrieval augmented generation Berbahasa Indonesia
#    Users: Henry Novianus Palit; Liliana
#    Distance: 0.9981
#
# 57. [36830] Sistem rekomendasi anime menggunakan metode user-based collaborative filtering berbasis k-means clustering
#    Users: Adi Wibowo; Justinus Andjarwirawan
#    Distance: 0.9984
#
# 58. [31249] Penerapan procedural content generation untuk generasi level dalam game mythical maze
#    Users: Liliana
#    Distance: 0.9989
#
# 59. [706] Evolutionary algorithm pada fuzzy clustering system dengan metode gustafson-kessel untuk forecasting electrical load data time-series
#    Users: Felix Pasila; Hany Ferdinando
#    Distance: 0.9992
#
# 60. [42186] Peran Guru Memanfaatkan AI dalam Membangun Generasi Unggul Menuju Indonesia Emas 2045. Aletheia Christian Educators Journal, 5 (1), 42–48
#    Users: Franky Boentolo
#    Distance: 1.0000
#
# 61. [32466] Meningkatkan variasi tindakan non-playable character pada game survival menggunakan metode markov
#    Users: Hans Juwiantho; Liliana
#    Distance: 1.0005
#
# 62. [35714] Visualisasi knapsack problem dan traveling salesman problem pada computational thinking dalam bentuk game dengan balancing artificial intelligence
#    Users: Liliana
#    Distance: 1.0006
#
# 63. [42706] Applications of artificial intelligence control for Parallel Discrete-Manipulators
#    Users: Roche Alimin; Felix Pasila
#    Distance: 1.0006
#
# 64. [22282] Perancangan dan pembuatan real-time game dengan menggunakan machine learning dan fuzzy rule-based untuk mengontrol pergerakan enemy
#    Users: Rolly Intan; Gregorius Satiabudhi
#    Distance: 1.0011
#
# 65. [42185] Peran guru memanfaatkan AI dalam membangun generasi unggul menuju Indonesia emas 2045
#    Users: Franky Boentolo
#    Distance: 1.0020
#
# 66. [15737] Representasi pesan LGBT dalam video musik populer Born This Way dan If I Had You
#    Users: Nanang Krisdinanto; Grace Swestin
#    Distance: 1.0025
#
# 67. [4984] Penjadualan flowshop dengan algoritma genetika
#    Users: Stevanus Adrianto Tjandra; Danny Prabowo Soetanto
#    Distance: 1.0039
#
# 68. [5253] Penjadwalan produksi flowshop dengan avolosionary algorithms untuk non unique jobs
#    Users: Pauline Astari Singgih; Didik Wahjudi
#    Distance: 1.0044
#
# 69. [17019] Konstruksi gender pada tokoh minions dalam film Despicable Me 2
#    Users: Fanny Lesmana; Jandy Edipson Luik
#    Distance: 1.0053
#
# 70. [37285] Leads categorization dengan support vector machine dan gaussian naive bayes untuk student admission pada Universitas X
#    Users: Adi Wibowo; Henry Novianus Palit
#    Distance: 1.0053
#
# 71. [20531] Pembuatan pengambilan keputusan untuk manajemen kerajaan lawan pada Game Majapahits Conquest
#    Users: Gregorius Satiabudhi; Liliana
#    Distance: 1.0074
#
# 72. [15044] Penjadwalan pengiriman barang di PT Simplot Agritama menggunakan algoritma genetika
#    Users: Yulius Untung; I Nyoman Sutapa
#    Distance: 1.0079
#
# 73. [671] Optimasi pola penyusunan barang dalam ruang tiga dimensi menggunakan metode genetic algorithms
#    Users: Irwan Kristanto Julistiono; Kartika Gunadi
#    Distance: 1.0080
#
# 74. [41676] Procedural Content Generation pada Game Tower Defense menggunakan Perlin Noise dan Algoritma Floyd Warshall
#    Users: Hans Juwiantho
#    Distance: 1.0083
#
# 75. [42291] Procedural Content Generation pada Game Tower Defense menggunakan Perlin Noise dan Algoritma Floyd Warshall
#    Users: Hans Juwiantho
#    Distance: 1.0083
#
# 76. [33056] Penerapan segmentasi warna menggunakan k-means clustering untuk pemilihan template dalam pembuatan konten
#    Users: Silvia Rostianingsih; Liliana
#    Distance: 1.0083
#
# 77. [24912] Implementasi fuzzy logic dan ellie: Buddy Ai pada companion dalam game survival horror
#    Users: Rudy Adipranata; Kristo Radion Purba S.St
#    Distance: 1.0084
#
# 78. [37326] Konsultasi studi di industri pendidikan: studi kasus universitas x memanfaatkan teknologi GPT (Generative Pre-Trained Transformer) open aI
#    Users: Adi Wibowo; Henry Novianus Palit
#    Distance: 1.0086
#
# 79. [26449] Pemanfaatan google assistant dan sistem rekomendasi untuk belajar alkitab
#    Users: Henry Novianus Palit; Leo Willyanto Santoso
#    Distance: 1.0089
#
# 80. [43946] Penerapan Algoritma Particle Swarm Optimization (PSO) untuk Optimisasi Pembangunan Negara dalam Turn Based Strategy Game
#    Users: Rudy Adipranata; Leo Willyanto Santoso
#    Distance: 1.0093
#
# 81. [20829] Analisa perbandingan algoritma kombinasi genetic & tabu search dengan metode Ant Colony pada permasalahan penjadwalan flowshop
#    Users: Tanti Octavia; Tessa Vanina Soetanto
#    Distance: 1.0094
#
# 82. [17519] Penggunaan linear programming dan genetic algorithms dalam menyelesaikan time-cost trade-off problem
#    Users: Paulus Nugraha
#    Distance: 1.0094
#
# 83. [44580] Designing Creative Learning Media About Processing of Used Milk Boxes into DIY Art and Craft
#    Users: Rika Febriani; Listia Natadjaja
#    Distance: 1.0096
#
# 84. [28957] Penerapan recurrent neural network untuk pembuatan ringkasan ekstraktif otomatis pada berita berbahasa Indonesia
#    Users: Henry Novianus Palit; Alvin Nathaniel Tjondrowiguno
#    Distance: 1.0097
#
# 85. [42820] Artificial Intelligence Tools for Research Writing: Practical Tips for Teachers
#    Users: Flora Debora Floris
#    Distance: 1.0099
#
# 86. [14802] Perancangan dan pembuatan aplikasi klasifikasi citra observasi bintik matahari menggunakan metode ID3 / C4.5
#    Users: Rudy Adipranata; Gregorius Satiabudhi
#    Distance: 1.0100
#
# 87. [10922] Simulasi dan analisa series active power filter tiga fasa dengan metode kompensasi artificial neural network
#    Users: Thiang; Hanny Hosiana Tumbelaka
#    Distance: 1.0100
#
# 88. [5175] Membandingkan algoritma tabu search ben-fawzan dengan solusi awal neh dan algoritma tabu search ben-fawzan dengan solusi awal CDS pada permasalahan Flow shop
#    Users: Sandy Citro; Tessa Vanina Soetanto
#    Distance: 1.0100
#
# 89. [11265] Pendjawalan flowshop dengan menggunakan algoritma genetika
#    Users: I Gede Agus Widyadana
#    Distance: 1.0104
#
# 90. [3596] Penggunaan algoritma genetika untuk merancang arsitektur jaringan saraf tiruan pada proses peramalan
#    Users: Siana Halim; Hany Ferdinando
#    Distance: 1.0104
#
# 91. [23789] Implementasi kombinasi jaringan syaraf tiruan metode self-organized map (SOM) dan bidirectional associative memory (BAM) pada AI game action adventure
#    Users: Gregorius Satiabudhi; Kristo Radion Purba S.St
#    Distance: 1.0111
#
# 92. [26506] Penerapan algoritma particle swarm optimization (PSO) untuk optimasi pembangunan negara dalam turn based strategy game
#    Users: Rudy Adipranata; Leo Willyanto Santoso
#    Distance: 1.0111
#
# 93. [26409] Identifikasi buah-buahan menggunakan metode convolutional neural network
#    Users: Kartika Gunadi
#    Distance: 1.0112
#
# 94. [40634] Penjadwalan produksi untuk meminimumkan setup time dan memaksimumkan aliran uang dengan metode genetic algorithm studi kasus pada CV. WP
#    Users: Herry Christian Palit; I Gede Agus Widyadana
#    Distance: 1.0141
#
# 95. [36845] Penerapan metode artificial intelligence untuk prediksi biaya awal proyek konstruksi bangunan
#    Users: Doddy Prayogo
#    Distance: 1.0148
#
# 96. [23802] Pembuatan aplikasi mobile augmented reality dengan scene recognition memanfaatkan convolutional neural network
#    Users: Gregorius Satiabudhi; Liliana
#    Distance: 1.0152
#
# 97. [40760] Perbandingan algoritma exhaustive, algoritma genetika dan algoritma jaringan syaraf tiruan hopfield untuk pencarian rute terpendek
#    Users: Rudy Adipranata; Felicia Soedjianto
#    Distance: 1.0154
#
# 98. [24669] Pendekatan hybrid genetic algorithm pada penjadwalan produksi di PT. Alas Petala Makmur
#    Users: Tessa Vanina Soetanto; Iwan Halim Sahputra
#    Distance: 1.0157
#
# 99. [39652] Analisa hybrid genetic algorithm pada permasalahan penjadwalan flowshop
#    Users: Tanti Octavia; Iwan Halim Sahputra
#    Distance: 1.0158
#
# 100. [6192] Genetic alogorithms dalam learning speech recognition berbasis neuro fuzzy untuk pengendalian kecepatan motor universal
#    Users: Yohanes T. D. S; Hany Ferdinando
#    Distance: 1.0160
#
#
# Top Users in Results:
# ==============================
# 1. Liliana (17 publications)
# 2. Doddy Prayogo (12 publications)
# 3. Henry Novianus Palit (11 publications)
# 4. Gregorius Satiabudhi (11 publications)
# 5. Leo Willyanto Santoso (8 publications)
# 6. Hans Juwiantho (7 publications)
# 7. Indar Sugiarto (7 publications)
# 8. Rolly Intan (6 publications)
# 9. Felix Pasila (6 publications)
# 10. Rudy Adipranata (5 publications)
# 11. Djoni Haryadi Setiabudi (4 publications)
# 12. Kristo Radion Purba S.St (4 publications)
# 13. Resmana Lim (4 publications)
# 14. Agustinus Noertjahyana (4 publications)
# 15. I Gede Agus Widyadana (4 publications)
# 16. Kartika Gunadi (3 publications)
# 17. Alvin Nathaniel Tjondrowiguno (3 publications)
# 18. Adi Wibowo (3 publications)
# 19. Hany Ferdinando (3 publications)
# 20. Tessa Vanina Soetanto (3 publications)
